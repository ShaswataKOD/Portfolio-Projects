# %% [markdown]
# # Data Wrangling
#
# > Exploring the Glassdoor job postings dataset to uncover valuable insights into job roles, industries, and salary trends. Starting with data cleaning to prepare the dataset for analysis by handling missing values, duplicates, and inconsistencies.

# %%
#Importing Libraries

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/data-science-job-posting-on-glassdoor/Uncleaned_DS_jobs.csv
# /kaggle/input/data-science-job-posting-on-glassdoor/Cleaned_DS_Jobs.csv

# %% [markdown]
# ## Structure Analysis

# %%
#reading the csv file
df = pd.read_csv("/kaggle/input/data-science-job-posting-on-glassdoor/Uncleaned_DS_jobs.csv")
df.shape
# Out:
# (672, 15)

# %%
# Randomly Sampled Data 

df.sample(10)
# Out:
#      index                                          Job Title  \
# 451    451                                     Data Scientist
# 650    650             Scientist / Group Lead, Cancer Biology
# 386    386                     Market Research Data Scientist
# 263    263                           Associate Data Scientist
# 518    518                     Data Science Software Engineer
# 181    181  Jr. Business Data Analyst (position added 6/12...
# 325    325                                      Data Engineer
# 237    237                                     Data Scientist
# 580    580  Vice President, Biometrics and Clinical Data M...
# 232    232                                     Data Scientist
#
#                   Salary Estimate  \
# 451   $69K-$116K (Glassdoor est.)
# 650   $92K-$155K (Glassdoor est.)
# 386  $110K-$163K (Glassdoor est.)
# 263   $91K-$150K (Glassdoor est.)
# 518  $212K-$331K (Glassdoor est.)
# 181    $56K-$97K (Glassdoor est.)
# 325   $79K-$147K (Glassdoor est.)
# 237   $71K-$123K (Glassdoor est.)
# 580  $138K-$158K (Glassdoor est.)
# 232   $71K-$123K (Glassdoor est.)
#
#                                        Job Description  Rating  \
# 451  By clicking continue you agree to Built In's P...     3.2
# 650  Scientist / Group Lead, Cancer Biology\nLocati...    -1.0
# 386  About Us\n\nAt GutCheck, we pioneered agile ma...     3.8
# 263  Puget Sound Energy is looking to grow our comm...     3.3
# 518  We love programming and the excitement that co...     4.8
# 181  April 2020 Update from WebFX: We're still acti...     4.7
# 325  About Rocket Lawyer\nWe believe everyone deser...     4.4
# 237  Who we are\n\n\nFueled by a fundamental belief...     3.8
# 580  At Alector, our mission is to develop therapie...     4.8
# 232  Headquartered in Lynchburg, Va., BWX Technolog...     3.3
#
#                 Company Name                 Location  \
# 451      The Trade Desk\n3.2              Boulder, CO
# 650  Monte Rosa Therapeutics            Cambridge, MA
# 386            GutCheck\n3.8               Denver, CO
# 263  Puget Sound Energy\n3.3              Bothell, WA
# 518             Klaviyo\n4.8               Boston, MA
# 181           webfx.com\n4.7           Harrisburg, PA
# 325       Rocket Lawyer\n4.4        San Francisco, CA
# 237              PayPal\n3.8                    Texas
# 580             Alector\n4.8  South San Francisco, CA
# 232    BWX Technologies\n3.3            Oak Ridge, TN
#
#                 Headquarters                     Size  Founded  \
# 451              Ventura, CA   1001 to 5000 employees     2009
# 650                       -1                       -1       -1
# 386               Denver, CO      51 to 200 employees     2009
# 263             Bellevue, WA   1001 to 5000 employees     1999
# 518               Boston, MA     201 to 500 employees     2012
# 181           Harrisburg, PA     201 to 500 employees     1997
# 325        San Francisco, CA      51 to 200 employees     2008
# 237             San Jose, CA         10000+ employees     1998
# 580  South San Francisco, CA      51 to 200 employees     2013
# 232            Lynchburg, VA  5001 to 10000 employees     1850
#
#      Type of ownership                      Industry  \
# 451   Company - Public                      Internet
# 650                 -1                            -1
# 386  Company - Private       Advertising & Marketing
# 263  Company - Private                     Utilities
# 518  Company - Private  Computer Hardware & Software
# 181  Company - Private       Advertising & Marketing
# 325  Company - Private  Computer Hardware & Software
# 237   Company - Public                      Internet
# 580   Company - Public     Biotech & Pharmaceuticals
# 232   Company - Public           Aerospace & Defense
#
#                            Sector                           Revenue  \
# 451        Information Technology          Unknown / Non-Applicable
# 650                            -1                                -1
# 386             Business Services          $10 to $25 million (USD)
# 263  Oil, Gas, Energy & Utilities            $2 to $5 billion (USD)
# 518        Information Technology          Unknown / Non-Applicable
# 181             Business Services          $25 to $50 million (USD)
# 325        Information Technology         $50 to $100 million (USD)
# 237        Information Technology                $10+ billion (USD)
# 580     Biotech & Pharmaceuticals          Unknown / Non-Applicable
# 232           Aerospace & Defense  $500 million to $1 billion (USD)
#
#                       Competitors
# 451                            -1
# 650                            -1
# 386  Nielsen, Zappi, SurveyMonkey
# 263                            -1
# 518                            -1
# 181                            -1
# 325                            -1
# 237         Square, Amazon, Apple
# 580                            -1
# 232                            -1

# %%
# Total Columns in the DataFrame

cols = df.columns
cols
# Out:
# Index(['index', 'Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors'],
#       dtype='object')

# %%
# Overview of Data Types 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 672 entries, 0 to 671
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              672 non-null    int64
#  1   Job Title          672 non-null    object
#  2   Salary Estimate    672 non-null    object
#  3   Job Description    672 non-null    object
#  4   Rating             672 non-null    float64
#  5   Company Name       672 non-null    object
#  6   Location           672 non-null    object
#  7   Headquarters       672 non-null    object
#  8   Size               672 non-null    object
#  9   Founded            672 non-null    int64
#  10  Type of ownership  672 non-null    object
#  11  Industry           672 non-null    object
#  12  Sector             672 non-null    object
#  13  Revenue            672 non-null    object
#  14  Competitors        672 non-null    object
# dtypes: float64(1), int64(2), object(12)
# memory usage: 78.9+ KB

# %% [markdown]
# ## Data Wrangling
# > * Removing Unnecessary Columns
# > * Checking for duplicate values
# > * Transforming missing or incomplete Data
# > * Inspecting Data Types
# > * Formatting Columns for further Exploratory Analysis

# %%
## Removing unnecessary columns

df.drop(columns=['Job Description','Headquarters'],inplace=True)

# %%
#Checking for any duplicated record 

df.duplicated().sum()   #resulted in no duplicated values
# Out:
# 0

# %%
# Inspecting Column by Column for any possible transformation


# Column : Job Title


df['Job Title'].value_counts() #Categorically splitting up the column

# %%
pd.set_option('display.max_rows',None) 
# Due to large number of cteogories, pandas view option is modified to display all results

df['Job Title']

# %%
#Script to categorize data

#function categorization takes each row of Job Title Column and 
# based on the logic converts them into 3 categories


def categorization(title):
    title = title.lower() 
    if "data scientist" in title:
        return "Data Scientist"
    elif "analytics" in title:
        return "Analyst"
    elif "engineer" in title:
        return "Engineer"
    else:
        return "Other"


df['job_category'] = df['Job Title'].apply(categorization) # creating a new feature upon applying the function

df['job_category'].value_counts() #checking the new categories

# %%
# column  : Salary estimate


df['Salary Estimate'][:5] #top 5 row values

# %%
# Transforming the Salary Estimate Column to numerical data from Categorical

df['Salary'] = df['Salary Estimate'].str.split('-').str[0]   #splitting the data from a delimiter 

#only the 0th index value is stored in the new column

#succesfully extracted the lower bounded values from the data




df['Salary']= df['Salary'].str.replace('$',"").str.replace('K', " ").astype('int') # String Values are replaced with blanks

#Further, the text data is converted to numerical values

# %%
#Column : Location 

#Splitting up the states from the cities 
# Broadly Categorizing data helps in Geospatial Analysis

df['State'] = df['Location'].str.split(',').str[1].str.strip()
#String is splitted from a blank space 
# The returning string value is stripped of any white spaces for efficient storage

# %%
#Cleanup of ownership column(Categorical)

df['Type of ownership'].value_counts()

# %%
# Putting the Strings in Correct format for easier analysis

# The function :
# 1. in case of a boolean match splits tthe strings and returns the values in the 1st index 
# 2. in case of a mismatch it defaults 

def change(values):
    if 'Company' in values:
        company,v = values.split('-')
        return v
    else:
        return 'Others'


#Modifyiing the original Column 
df['Type of ownership'] = df['Type of ownership'].apply(change)

# %%
df['Type of ownership'].value_counts()  #Succesfull Transformation

# %%
## Column : sectors(Categorical)


# Enhanced code readability with lambda function, gracefully handling the null values 

df['Sector'] = df['Sector'].apply(lambda x: 'Others' if x== -1 else x)

# %%
#Column : Company Name


#removed the new line character from the Company Name enhancing readability

def name_change(values):
    if '\n' in values:
        return values.replace("\n","")


df['Company Name'].apply(name_change)

# %%
##dropping unnecessary columns and renaming the necessities

df.drop(columns=['index','Job Title','Salary Estimate','Location'], inplace=True)

# %% [markdown]
# ## End of Data Wrangling

# %%
#Exporting the new Data Frame for Analysis

df.to_csv("JobLists.csv",index=False)  #stores the csv file in the current working directory
